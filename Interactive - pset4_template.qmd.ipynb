# %% [markdown]
# Connected to Python 3.10.0

# %%
import pandas as pd
import geopandas as gpd
import shapely

pos2016 = pd.read_csv('/Users/jennyzhong/Documents/GitHub/problem-set-4-summer-jenny/pos2016.csv')

pos2016.head(10)
pos2016.tail(10)
# Out:
# /Users/jennyzhong/Library/Python/3.10/lib/python/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)
#         PRVDR_CTGRY_SBTYP_CD  PRVDR_CTGRY_CD  CHOW_CNT  CHOW_DT    CITY_NAME  \
# 141547                   1.0              21         0      NaN      SPOKANE
# 141548                   1.0              21         0      NaN      GRANGER
# 141549                   1.0              21         0      NaN        AMBER
# 141550                   1.0              21         0      NaN      SEATTLE
# 141551                   1.0              21         0      NaN     ENUMCLAW
# 141552                   1.0              21         0      NaN    BREMERTON
# 141553                   1.0              21         0      NaN  CASTLE ROCK
# 141554                   1.0              21         0      NaN       RENTON
# 141555                   1.0              21         0      NaN     BELLEVUE
# ...

# %%
import pandas as pd
import geopandas as gpd
import shapely

pos2016 = pd.read_csv('/Users/jennyzhong/Documents/GitHub/problem-set-4-summer-jenny/pos2016.csv')

pos2016.head(10)
# Out:
#    PRVDR_CTGRY_SBTYP_CD  PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT     CITY_NAME  \
# 0                   1.0               1         1         NaN        DOTHAN
# 1                   1.0               1         0         NaN    BRIDGEPORT
# 2                   1.0               1         0         NaN          BOAZ
# 3                   1.0               1         1  20100701.0      FLORENCE
# 4                   1.0               1         0         NaN           OPP
# 5                   1.0               1         1  20020701.0       LUVERNE
# 6                   1.0               1         3         NaN     HARTSELLE
# 7                   1.0               1         0         NaN  GUNTERSVILLE
# 8                   1.0               1         1         NaN    BIRMINGHAM
# 9                   1.0               1         1  20060401.0    FORT PAYNE
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# ...

# %%
#focusing on short term hospitals 
pos2016['PRVDR_CTGRY_SBTYP_CD'] = pos2016['PRVDR_CTGRY_SBTYP_CD'].astype(str).str.zfill(2)

pos2016['PRVDR_CTGRY_CD'] = pos2016['PRVDR_CTGRY_CD'].astype(str).str.zfill(2)

# %%
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == '01') & (pos2016['PRVDR_CTGRY_CD'] == '01')]

# %%
print(pos2016)
print(st_hospitals.head())
# Out:
#        PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT    CITY_NAME  \
# 0                       1.0             01         1         NaN       DOTHAN
# 1                       1.0             01         0         NaN   BRIDGEPORT
# 2                       1.0             01         0         NaN         BOAZ
# 3                       1.0             01         1  20100701.0     FLORENCE
# 4                       1.0             01         0         NaN          OPP
# ...                     ...            ...       ...         ...          ...
# 141552                  1.0             21         0         NaN    BREMERTON
# 141553                  1.0             21         0         NaN  CASTLE ROCK
# 141554                  1.0             21         0         NaN       RENTON
# 141555                  1.0             21         0         NaN     BELLEVUE
# 141556                  1.0             21         0         NaN      SEATTLE
#
# ...

# %%
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == '1.0') & (pos2016['PRVDR_CTGRY_CD'] == '01')]

# %%
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == '1.0') & (pos2016['PRVDR_CTGRY_CD'] == '01')]

# %%
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == '1.0') & (pos2016['PRVDR_CTGRY_CD'] == '01')]

print(st_hospitals.head())
# Out:
#   PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT   CITY_NAME  \
# 0                  1.0             01         1         NaN      DOTHAN
# 1                  1.0             01         0         NaN  BRIDGEPORT
# 2                  1.0             01         0         NaN        BOAZ
# 3                  1.0             01         1  20100701.0    FLORENCE
# 4                  1.0             01         0         NaN         OPP
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# 1            NORTH JACKSON HOSPITAL    010004              1
# 2     MARSHALL MEDICAL CENTER SOUTH    010005              0
# 3    ELIZA COFFEE MEMORIAL HOSPITAL    010006              0
# 4          MIZELL MEMORIAL HOSPITAL    010007              0
#
#    TRMNTN_EXPRTN_DT   ZIP_CD
# 0               NaN  36301.0
# 1        20010831.0  35740.0
# 2               NaN  35957.0
# 3               NaN  35631.0
# ...

# %%
print(st_hospitals.head())
# Out:
#   PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT   CITY_NAME  \
# 0                  1.0             01         1         NaN      DOTHAN
# 1                  1.0             01         0         NaN  BRIDGEPORT
# 2                  1.0             01         0         NaN        BOAZ
# 3                  1.0             01         1  20100701.0    FLORENCE
# 4                  1.0             01         0         NaN         OPP
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# 1            NORTH JACKSON HOSPITAL    010004              1
# 2     MARSHALL MEDICAL CENTER SOUTH    010005              0
# 3    ELIZA COFFEE MEMORIAL HOSPITAL    010006              0
# 4          MIZELL MEMORIAL HOSPITAL    010007              0
#
#    TRMNTN_EXPRTN_DT   ZIP_CD
# 0               NaN  36301.0
# 1        20010831.0  35740.0
# 2               NaN  35957.0
# 3               NaN  35631.0
# ...

# %%
import pandas as pd
import geopandas as gpd
import shapely

pos2016 = pd.read_csv('/Users/jennyzhong/Documents/GitHub/problem-set-4-summer-jenny/pos2016.csv')

pos2016.head(10)
# Out:
#    PRVDR_CTGRY_SBTYP_CD  PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT     CITY_NAME  \
# 0                   1.0               1         1         NaN        DOTHAN
# 1                   1.0               1         0         NaN    BRIDGEPORT
# 2                   1.0               1         0         NaN          BOAZ
# 3                   1.0               1         1  20100701.0      FLORENCE
# 4                   1.0               1         0         NaN           OPP
# 5                   1.0               1         1  20020701.0       LUVERNE
# 6                   1.0               1         3         NaN     HARTSELLE
# 7                   1.0               1         0         NaN  GUNTERSVILLE
# 8                   1.0               1         1         NaN    BIRMINGHAM
# 9                   1.0               1         1  20060401.0    FORT PAYNE
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# ...

# %%
#focusing on short term hospitals 
pos2016['PRVDR_CTGRY_SBTYP_CD'] = pos2016['PRVDR_CTGRY_SBTYP_CD'].astype(str).str.zfill(2)

pos2016['PRVDR_CTGRY_CD'] = pos2016['PRVDR_CTGRY_CD'].astype(str).str.zfill(2)

# %%
#focusing on short term hospitals 
pos2016['PRVDR_CTGRY_SBTYP_CD'] = pos2016['PRVDR_CTGRY_SBTYP_CD'].astype(str).str.zfill(2)

pos2016['PRVDR_CTGRY_CD'] = pos2016['PRVDR_CTGRY_CD'].astype(str).str.zfill(2)
pos2016.head()
# Out:
#   PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT   CITY_NAME  \
# 0                  1.0             01         1         NaN      DOTHAN
# 1                  1.0             01         0         NaN  BRIDGEPORT
# 2                  1.0             01         0         NaN        BOAZ
# 3                  1.0             01         1  20100701.0    FLORENCE
# 4                  1.0             01         0         NaN         OPP
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# 1            NORTH JACKSON HOSPITAL    010004              1
# 2     MARSHALL MEDICAL CENTER SOUTH    010005              0
# 3    ELIZA COFFEE MEMORIAL HOSPITAL    010006              0
# 4          MIZELL MEMORIAL HOSPITAL    010007              0
#
#    TRMNTN_EXPRTN_DT   ZIP_CD
# 0               NaN  36301.0
# 1        20010831.0  35740.0
# 2               NaN  35957.0
# 3               NaN  35631.0
# ...

# %%
import pandas as pd
import geopandas as gpd
import shapely

pos2016 = pd.read_csv('/Users/jennyzhong/Documents/GitHub/problem-set-4-summer-jenny/pos2016.csv')

pos2016.head(10)
# Out:
#    PRVDR_CTGRY_SBTYP_CD  PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT     CITY_NAME  \
# 0                   1.0               1         1         NaN        DOTHAN
# 1                   1.0               1         0         NaN    BRIDGEPORT
# 2                   1.0               1         0         NaN          BOAZ
# 3                   1.0               1         1  20100701.0      FLORENCE
# 4                   1.0               1         0         NaN           OPP
# 5                   1.0               1         1  20020701.0       LUVERNE
# 6                   1.0               1         3         NaN     HARTSELLE
# 7                   1.0               1         0         NaN  GUNTERSVILLE
# 8                   1.0               1         1         NaN    BIRMINGHAM
# 9                   1.0               1         1  20060401.0    FORT PAYNE
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# ...

# %%
import pandas as pd
import geopandas as gpd
import shapely

pos2016 = pd.read_csv('/Users/jennyzhong/Documents/GitHub/problem-set-4-summer-jenny/pos2016.csv')

pos2016.head(10)
# Out:
#    PRVDR_CTGRY_SBTYP_CD  PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT     CITY_NAME  \
# 0                   1.0               1         1         NaN        DOTHAN
# 1                   1.0               1         0         NaN    BRIDGEPORT
# 2                   1.0               1         0         NaN          BOAZ
# 3                   1.0               1         1  20100701.0      FLORENCE
# 4                   1.0               1         0         NaN           OPP
# 5                   1.0               1         1  20020701.0       LUVERNE
# 6                   1.0               1         3         NaN     HARTSELLE
# 7                   1.0               1         0         NaN  GUNTERSVILLE
# 8                   1.0               1         1         NaN    BIRMINGHAM
# 9                   1.0               1         1  20060401.0    FORT PAYNE
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# ...

# %%
#focusing on short term hospitals 
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == 1.0) & (pos2016['PRVDR_CTGRY_CD'] == 1)]
st_hospitals.head()
# Out:
#    PRVDR_CTGRY_SBTYP_CD  PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT   CITY_NAME  \
# 0                   1.0               1         1         NaN      DOTHAN
# 1                   1.0               1         0         NaN  BRIDGEPORT
# 2                   1.0               1         0         NaN        BOAZ
# 3                   1.0               1         1  20100701.0    FLORENCE
# 4                   1.0               1         0         NaN         OPP
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# 1            NORTH JACKSON HOSPITAL    010004              1
# 2     MARSHALL MEDICAL CENTER SOUTH    010005              0
# 3    ELIZA COFFEE MEMORIAL HOSPITAL    010006              0
# 4          MIZELL MEMORIAL HOSPITAL    010007              0
#
#    TRMNTN_EXPRTN_DT   ZIP_CD
# 0               NaN  36301.0
# 1        20010831.0  35740.0
# 2               NaN  35957.0
# 3               NaN  35631.0
# ...

# %%
#focusing on short term hospitals 
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == 1.0) & (pos2016['PRVDR_CTGRY_CD'] == 1)]
st_hospitals.head()
st_hospitals.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Users/jennyzhong/Documents/GitHub/problem-set-4-summer-jenny/pset4_template.qmd:4
#       2 st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == 1.0) & (pos2016['PRVDR_CTGRY_CD'] == 1)]
#       3 st_hospitals.head()
# ----> 4 st_hospitals.shape()
#
# TypeError: 'tuple' object is not callable

# %%
#focusing on short term hospitals 
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == 1.0) & (pos2016['PRVDR_CTGRY_CD'] == 1)]
st_hospitals.head()
st_hospitals.shape
# Out:
# (7245, 10)

# %%
#focusing on short term hospitals 
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == 1.0) & (pos2016['PRVDR_CTGRY_CD'] == 1)]
st_hospitals.head()
st_hospitals.shape
pos2016.shape
# Out:
# (141557, 10)

# %%
#focusing on short term hospitals 
pos2016['PRVDR_CTGRY_SBTYP_CD'] = pos2016['PRVDR_CTGRY_SBTYP_CD'].astype(str).str.zfill(2)

pos2016['PRVDR_CTGRY_CD'] = pos2016['PRVDR_CTGRY_CD'].astype(str).str.zfill(2)
pos2016.head()
# Out:
#   PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT   CITY_NAME  \
# 0                  1.0             01         1         NaN      DOTHAN
# 1                  1.0             01         0         NaN  BRIDGEPORT
# 2                  1.0             01         0         NaN        BOAZ
# 3                  1.0             01         1  20100701.0    FLORENCE
# 4                  1.0             01         0         NaN         OPP
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# 1            NORTH JACKSON HOSPITAL    010004              1
# 2     MARSHALL MEDICAL CENTER SOUTH    010005              0
# 3    ELIZA COFFEE MEMORIAL HOSPITAL    010006              0
# 4          MIZELL MEMORIAL HOSPITAL    010007              0
#
#    TRMNTN_EXPRTN_DT   ZIP_CD
# 0               NaN  36301.0
# 1        20010831.0  35740.0
# 2               NaN  35957.0
# 3               NaN  35631.0
# ...

# %%
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == '1.0') & (pos2016['PRVDR_CTGRY_CD'] == '01')]

print(st_hospitals.head())
# Out:
#   PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT   CITY_NAME  \
# 0                  1.0             01         1         NaN      DOTHAN
# 1                  1.0             01         0         NaN  BRIDGEPORT
# 2                  1.0             01         0         NaN        BOAZ
# 3                  1.0             01         1  20100701.0    FLORENCE
# 4                  1.0             01         0         NaN         OPP
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# 1            NORTH JACKSON HOSPITAL    010004              1
# 2     MARSHALL MEDICAL CENTER SOUTH    010005              0
# 3    ELIZA COFFEE MEMORIAL HOSPITAL    010006              0
# 4          MIZELL MEMORIAL HOSPITAL    010007              0
#
#    TRMNTN_EXPRTN_DT   ZIP_CD
# 0               NaN  36301.0
# 1        20010831.0  35740.0
# 2               NaN  35957.0
# 3               NaN  35631.0
# ...

# %%
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == '1.0') & (pos2016['PRVDR_CTGRY_CD'] == '01')]

print(st_hospitals.head())
st_hospitals.shape
# Out:
#   PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT   CITY_NAME  \
# 0                  1.0             01         1         NaN      DOTHAN
# 1                  1.0             01         0         NaN  BRIDGEPORT
# 2                  1.0             01         0         NaN        BOAZ
# 3                  1.0             01         1  20100701.0    FLORENCE
# 4                  1.0             01         0         NaN         OPP
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# 1            NORTH JACKSON HOSPITAL    010004              1
# 2     MARSHALL MEDICAL CENTER SOUTH    010005              0
# 3    ELIZA COFFEE MEMORIAL HOSPITAL    010006              0
# 4          MIZELL MEMORIAL HOSPITAL    010007              0
#
#    TRMNTN_EXPRTN_DT   ZIP_CD
# 0               NaN  36301.0
# 1        20010831.0  35740.0
# 2               NaN  35957.0
# 3               NaN  35631.0
# ...

# %%
#focusing on short term hospitals 
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == 1.0) & (pos2016['PRVDR_CTGRY_CD'] == 1)]

# %%
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == '1.0') & (pos2016['PRVDR_CTGRY_CD'] == '01')]

print(st_hospitals.head())
st_hospitals.shape
# Out:
#   PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT   CITY_NAME  \
# 0                  1.0             01         1         NaN      DOTHAN
# 1                  1.0             01         0         NaN  BRIDGEPORT
# 2                  1.0             01         0         NaN        BOAZ
# 3                  1.0             01         1  20100701.0    FLORENCE
# 4                  1.0             01         0         NaN         OPP
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# 1            NORTH JACKSON HOSPITAL    010004              1
# 2     MARSHALL MEDICAL CENTER SOUTH    010005              0
# 3    ELIZA COFFEE MEMORIAL HOSPITAL    010006              0
# 4          MIZELL MEMORIAL HOSPITAL    010007              0
#
#    TRMNTN_EXPRTN_DT   ZIP_CD
# 0               NaN  36301.0
# 1        20010831.0  35740.0
# 2               NaN  35957.0
# 3               NaN  35631.0
# ...

# %%
st_hospitals = pos2016[(pos2016['PRVDR_CTGRY_SBTYP_CD'] == '1.0') & (pos2016['PRVDR_CTGRY_CD'] == '01')]

print(st_hospitals.head())
st_hospitals.shape
# Out:
#   PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT   CITY_NAME  \
# 0                  1.0             01         1         NaN      DOTHAN
# 1                  1.0             01         0         NaN  BRIDGEPORT
# 2                  1.0             01         0         NaN        BOAZ
# 3                  1.0             01         1  20100701.0    FLORENCE
# 4                  1.0             01         0         NaN         OPP
#
#                            FAC_NAME PRVDR_NUM  PGM_TRMNTN_CD  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER    010001              0
# 1            NORTH JACKSON HOSPITAL    010004              1
# 2     MARSHALL MEDICAL CENTER SOUTH    010005              0
# 3    ELIZA COFFEE MEMORIAL HOSPITAL    010006              0
# 4          MIZELL MEMORIAL HOSPITAL    010007              0
#
#    TRMNTN_EXPRTN_DT   ZIP_CD
# 0               NaN  36301.0
# 1        20010831.0  35740.0
# 2               NaN  35957.0
# 3               NaN  35631.0
# ...

# %%
st_hospitals['YEAR'] = 2016
# Out:
# <ipython-input-25-2e0735bf06d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_hospitals['YEAR'] = 2016

# %%
st_hospitals['YEAR'] = 2016
st_hospitals.shape
# Out:
# <ipython-input-26-2f78f117b6bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_hospitals['YEAR'] = 2016
# (7245, 11)

# %%
st_hospitals['YEAR'] = 2016
print(st_hospitals)
# Out:
#        PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT  \
# 0                       1.0             01         1         NaN
# 1                       1.0             01         0         NaN
# 2                       1.0             01         0         NaN
# 3                       1.0             01         1  20100701.0
# 4                       1.0             01         0         NaN
# ...                     ...            ...       ...         ...
# 133526                  1.0             01         0         NaN
# 133527                  1.0             01         0         NaN
# 133528                  1.0             01         0         NaN
# 133529                  1.0             01         0         NaN
# 133530                  1.0             01         0         NaN
#
#            CITY_NAME                          FAC_NAME PRVDR_NUM  \
# 0             DOTHAN  SOUTHEAST ALABAMA MEDICAL CENTER    010001
# ...

# %%
st_hospitals = st_hospitals.copy()
st_hospitals['YEAR'] = 2016
print(st_hospitals)
# Out:
#        PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT  \
# 0                       1.0             01         1         NaN
# 1                       1.0             01         0         NaN
# 2                       1.0             01         0         NaN
# 3                       1.0             01         1  20100701.0
# 4                       1.0             01         0         NaN
# ...                     ...            ...       ...         ...
# 133526                  1.0             01         0         NaN
# 133527                  1.0             01         0         NaN
# 133528                  1.0             01         0         NaN
# 133529                  1.0             01         0         NaN
# 133530                  1.0             01         0         NaN
#
#            CITY_NAME                          FAC_NAME PRVDR_NUM  \
# 0             DOTHAN  SOUTHEAST ALABAMA MEDICAL CENTER    010001
# ...

# %%
st_hospitals = st_hospitals.copy()
st_hospitals['YEAR'] = 2016
print(st_hospitals)
# Out:
#        PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT  \
# 0                       1.0             01         1         NaN
# 1                       1.0             01         0         NaN
# 2                       1.0             01         0         NaN
# 3                       1.0             01         1  20100701.0
# 4                       1.0             01         0         NaN
# ...                     ...            ...       ...         ...
# 133526                  1.0             01         0         NaN
# 133527                  1.0             01         0         NaN
# 133528                  1.0             01         0         NaN
# 133529                  1.0             01         0         NaN
# 133530                  1.0             01         0         NaN
#
#            CITY_NAME                          FAC_NAME PRVDR_NUM  \
# 0             DOTHAN  SOUTHEAST ALABAMA MEDICAL CENTER    010001
# ...

# %%
st_hospitals = st_hospitals.copy()
st_hospitals['YEAR'] = 2016
print(st_hospitals)
# Out:
#        PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT  \
# 0                       1.0             01         1         NaN
# 1                       1.0             01         0         NaN
# 2                       1.0             01         0         NaN
# 3                       1.0             01         1  20100701.0
# 4                       1.0             01         0         NaN
# ...                     ...            ...       ...         ...
# 133526                  1.0             01         0         NaN
# 133527                  1.0             01         0         NaN
# 133528                  1.0             01         0         NaN
# 133529                  1.0             01         0         NaN
# 133530                  1.0             01         0         NaN
#
#            CITY_NAME                          FAC_NAME PRVDR_NUM  \
# 0             DOTHAN  SOUTHEAST ALABAMA MEDICAL CENTER    010001
# ...

# %%
st_hospitals = st_hospitals.copy()
st_hospitals['YEAR'] = 2016
print(st_hospitals)
# Out:
#        PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT  \
# 0                       1.0             01         1         NaN
# 1                       1.0             01         0         NaN
# 2                       1.0             01         0         NaN
# 3                       1.0             01         1  20100701.0
# 4                       1.0             01         0         NaN
# ...                     ...            ...       ...         ...
# 133526                  1.0             01         0         NaN
# 133527                  1.0             01         0         NaN
# 133528                  1.0             01         0         NaN
# 133529                  1.0             01         0         NaN
# 133530                  1.0             01         0         NaN
#
#            CITY_NAME                          FAC_NAME PRVDR_NUM  \
# 0             DOTHAN  SOUTHEAST ALABAMA MEDICAL CENTER    010001
# ...

# %%
st_hospitals.loc[:, 'YEAR'] = 2016

print(st_hospitals)
# Out:
#        PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD  CHOW_CNT     CHOW_DT  \
# 0                       1.0             01         1         NaN
# 1                       1.0             01         0         NaN
# 2                       1.0             01         0         NaN
# 3                       1.0             01         1  20100701.0
# 4                       1.0             01         0         NaN
# ...                     ...            ...       ...         ...
# 133526                  1.0             01         0         NaN
# 133527                  1.0             01         0         NaN
# 133528                  1.0             01         0         NaN
# 133529                  1.0             01         0         NaN
# 133530                  1.0             01         0         NaN
#
#            CITY_NAME                          FAC_NAME PRVDR_NUM  \
# 0             DOTHAN  SOUTHEAST ALABAMA MEDICAL CENTER    010001
# ...
